# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergrey5571/Sergrey5571/blob/main/%D0%9A%D0%B5%D0%B9%D1%81_%E2%84%9634.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Гарбузов Сергей Юрьевич**
#
#  **Обучение:** Финансовый Университет при правительстве РФ.
#
#   **Сроки обучения:** 26 сентября 2022г. - 26 декабря 2022г.
#
#   **Форма обучения:** дистанционная очно-заочное

# %% [markdown]
# # Задание. Кейс №34

# %% [markdown]
# ## Описание кейса

# %% [markdown]
# Для итоговой работы представлен **кейс №34** в виде четырёх таблиц в формате Excel(Sales, Region, Products, Customer соотвественно)
#
#
#
# ---
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Расшифровка колонок из таблиц:**
# 1. **OrderDate** - Дата заказа
# 2. **Wholesale** - оптовые продажи
# 3. **Currency Code** - код валюты
# 4. **Warehouse Code** - код склада
# 5. **Delivery Region Index** - индекс региона доставки
# 6. **Product Description Index** - индекс описания продукта
# 7. **Order Quantity** - количество заказанного
# 8. **Unit Price** - цена за единицу
# 9. **Line Total** - итого по стороке
# 10. **Total Unit Cost** - общая стоимость единицы
# 11. **Customer Name Index** - указатель имён клиентов
# 12. **Region Sales** - регион продаж
# 13. **Region Group** - группа регионов
# 14. **Product Sales** - продажи продукции
# 15. **Customer Sales** - продажи клиентов

# %% [markdown]
# ---
# **Описание таблиц:**
#
#
# 1.   **Таблица №1**: описывает оптовые продажи в долларах с указанием номера заказа, себестоимости, цены продажи, количества и общей суммы по заказу продукта. Также указана дата покупки или продажи (OrderData, Channel) компаний, используя индекс.
# 2.   **Таблица №2:** описывает продажи по регионам стран и городов этих стран. Также таблица включает рейтинг регионов.
# 3.   **Таблица №3:** описывает общие продажи по наименованию продуктов.
# 4.   **Таблица №4:** описывает общие продажи по компаниям.

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# **Задача:** На основании представленных таблиц кейса №34 провести анализ компаний по продажам в регионах в промежуток времени с 2014 по 2017 годов, и сделать общие выводы для принятия решений специалистами в данной области.
#
# **Цель:** На практике показать свои навыки и знания, полученные мною на  курсе  "Аналитика Больших Данных".
#
# ---

# %% [markdown]
# # Начало анализа. Loginom и сопутствующая аналитика.

# %% [markdown]
# https://drive.google.com/file/d/1ses5UEhvgp4POCPlxhp4M235JcHl9mWv/view?usp=share_link Посмотреть возможно после скачивания.

# %% [markdown]
# Цель раздела, объединить, преобразовать и провести статистистический и визуальный анализ вышеуказанных таблиц. Конечной задачей будет, насытить и привести в нужный формат таблицу данными для последующего анализа. Попробовать на настольной версии продукта создать модель  для машинного обучения и провести одну из гипотез исследования маркетинга компаний. Для этой цели использую российский продукт Desktop Loginom Community version 6.5.5 .

# %% [markdown]
# ##насыщение и подготовка данных.анализ.

# %% [markdown]
# ---

# %% [markdown]
# Для загрузки таблиц в Loginom используем облачную платформу BigQuery

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В программе Loginom проводим слияние таблиц. Также при слиянии очищаем данные. Все манипуляции с данными производим в отдельных блоках, показанных ниже.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# После слияния, можно посмотреть общие статистические характеристики по столбцам.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   В данной статистической таблице, без знания языков программирования можно увидеть :минимум, максимум, среднее и т.д. по каждому столбцу. Также, наглядно представлены основные показатели распределения. Так, в данной таблице, можно сделать первые описательные выводы, такие как:
#
#
# *   Наблюдения ведутся с 1 июня 2014г. по 1 января 2017г.
# *   В среднем компании на один заказ тратят около 19 350 $
# *   В наблюдениях участвуют 50 компаний из 26 стран и 66 городов
# *   В ассортименте продаж 14 видов продуктов(не указаны каких), где доля в продажах преимущество занимают продукты 1,2 и 7
#
# Также в Loginom можно создавать сводные таблицы и сразу представить их в графическом виде, с помощью функционала куба в программе, что делает программу универсальной уже на начальном уровне.
# Но т.к. нужно ещё насытить данные для проведения более расширенного анализа, пока оставим выводы на более поздний этап.

# %% [markdown]
# На следующем этапе необходимо провести ABC_XYZ и RFM анализ и результаты добавить в таблицу. Для этого производим группировку и очистку данных в отдельных блоках.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# подробнее:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Какие выводы здесь.
#
# ---
# ABC_XYZ анализ показал, что присутствует девять уникальных сочетаний. Большая часть сочетаний приходятся на сочетаниях AY, BY, CY. В первую очередь, здесь просматривается условно стабильный спрос(62%) на продукцию при изменении объёмов продаж. Также можно отметить, при продажах товаров от случая к случаю, выручка всё равно высокая. Т.к. я брал небольшой диапазон коэффициентов, то можно сказать, что компании работают с хорошей выручкой и стабильным спросом. Работу отдельно по компаниям рассмотрим позже.

# %% [markdown]
# ---
# **RFM анализ:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Собственно говоря,можно лишь потвердить результаты ABC анализа. 25 вариантов распределения давности,частоте и монетизации распределены примерно одинаково, что говорит у компаний сильных перекосов нет.

# %% [markdown]
# ---
# Следующим шагом будет, слияние полученных данных с исходной таблицей, полученной из Bigquery  и также добавляю туда же значения маржи и прибыли. на выходе получился Датасет с 25 столбцами и 8000 строками. Также был добавлен столбец (Churn) оттока компаний (вероятность их закрытия). Тут, конечно можно сказать, что этот кейс не подходит для данного исследования. Тем не менее, всё же, чисто гипотетически можно представить. Делал,исходя из того, что компания ничего делать не будет в течении 150 дней. Вероятность получилась, что 86% компаний не закроется и соответственно 14% закроются. Опять же пример, чисто показательный на знание инструментов работы с приложением. После, записываем полученные данные в формат csv и Loginom Data. Также, сделаем, для упрощения, в колабе ещё пару файлов для дальшейшей работы.

# %% [markdown]
# ##логистическая регрессия в Loginom

# %% [markdown]
# Попробуем, провести машинное обучение на предмет логистической регрессии по столбцу Churn(отток). Логичней бы запустить прогнозирование продаж, но в наличие слабенький компьютер. Пробовал, не потянул. Моделирование будет проводится исходя из 80% (6667 значений) обучающей и 20%(1234) тестовой выборок. Участвуют 23 столбца и 8000 строк. Какие результаты получаем:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Можно считать, что модель отработала хорошо.  Распознано **91,63%**. Если считать, что вручную ничего не подгонял и не настраивал, то это очень не плохой результат. Loginom справился с задачей машинного обучения, при не большом наборе данных. Запомним результат.

# %% [markdown]
# # Разведовательный анализ. EDA

# %% [markdown]
# файл csv из Loginom https://drive.google.com/file/d/1_Z8FOQaxQFOvW-dh7GVaYm-I0E9z-SdR/view?usp=share_link

# %% [markdown]
# Данный раздел описывает данные полученные в Loginom, взаимосвязи между ними, их информативность и значимость. Для этого будет использоватся облачный сервис Google Colab и фреймворки на языке Python.

# %% [markdown]
# ## библиотека 	**pandas-profiling vv3.6.1**

# %% [markdown]
# Создадим отчёт по EDA с данной библиотекой

# %% [markdown]
# ссылка на блокнот https://colab.research.google.com/drive/1xp46UZlplId2jGNUEosHyqyStXJf7kh8?usp=sharing

# %% [markdown]
# наиболее информативные моменты

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Здесь показано распределение стоимости товаров по чеку, на котором виден не большой перекос в значениях среднего и медианы. Как и везде, в жизни получается, что наиболее дешёвый чек с большим количеством не покрывает чеки с небольшим количеством, но высокой ценой. Как и видели в Лоджином среднее значение также показывает 19 345 $

# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Отток и отток 1234 значения, но вернёмся к Loginom. Там модель, хоть и с ошибкой, предсказала отток 1466, т.е. в большую сторону. Модель посчитала, что уходить будут больше. Тут уже есть над чем подумать специалистам в данной области.

# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Как и в Loginom( описывал выше) лидируют в продажах продукты 7, 1, 2

# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Все эти выкладки можно было взять и в Loginom, но у меня другая цель. Итак, в сокупности компании работают со стабильной выручкой, даже при изменении объёма продаж. Основная деятельность, это оптовые продажи. На фоне других компаний, активнее всего проявляют себя компании Medline, Eminence Corp, Elorac, Corp, Apotheca Ltd, Apollo Ltd. Наибольшая деятельность проявляется в Германии, однако, если выбирать по городам Европы, то немецкие города не попадают в тройку по активности. Первые три строчки занимают Барселона Милан и Палермо. Последняя гистограмма показывает, на каких складах ведётся наиболее активность.

# %% [markdown]
# ## библиотека LUX

# %% [markdown]
# ссылка на блокнот https://colab.research.google.com/drive/12N0STwEc7JaKjbGvVwEDTrh3u80TJw-a?usp=sharing

# %% [markdown]
# Этой библиотеки в курсе обучения нет, но курс и предназначен, чтобы студент научился находить нужную информацию, для достижения цели. Здесь я дополню информацию о данных, которые были описаны выше.

# %% [markdown]
# Итак вернёмся к **городам и странам**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Что интересного тут замечено. Самая стабильная работа происходит в Барселоне. В четырёх представленных графиков видно, что город Наполи (Италия), при высокой суммарной прибыли и активности на складах, имеет высокий процент закрытия. Этот вопрос надо разбирать со специалистами (маркетологами, логистами). Это отдельная тема, но думаю (если углубиться в этот вопрос), что надо посмотреть на АВСXYZ анализ.

# %% [markdown]
# ---
# **по компаниям**

# %% [markdown]
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %% [markdown]
# Наиболее успешной, хоть и с не большим отрывом, можно признать компанию Medline. По стабильности и выручке уступает лишь Eminence Corp. Самая активная деятельность проходит в Германии, но если брать по городам, то самое частое явление находится в Будапеште(Венгрия). В ТОР 10 различных величин, исходя из этих диаграмм встречаются одни и теже компании, что говорит о высокой конкуренции.

# %% [markdown]
# **по временным интервалам**

# %% [markdown]
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %% [markdown]
# в период с 2014 года по 2017 год деятельность компаний можно назвать стабильной. Есть небольшой рост в середине лета, но сезонностью назвать это трудно.Есть прекращение деятельности в конце года, но это легко объяснить. Компании закрываются на праздники. Если понимать таблицу и названия компаний, то можно заметить, что под названием "продукт" следует понимать какие то медицинские названия (обрудование, препараты, и т.д.). Есть ещё одно интересное наблюдение. Это отток. Вероятность его приходится только на первый год, на уровне стартапа. Но после 2015года ситуация выровнялась. Собственно говоря, дальнейший анализ по параметру "уходит, не уходит" теряет смысл. Но гипотеза проверена. Всё равно продолжу. Она может пригодится на уровне стартапа, когда можно прогнозировать при каких обстоятельствах возмоожно закрытие, и как компании выходили из этой ситуации, и не делать ошибок.

# %% [markdown]
# **по суммарной прибыли**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %% [markdown]
# Здесь есть интересные наблюдения. Барселона меня не удивила. С большой прибылью компании находятся в Германии, однако в рейтинг затисалась компания ETUDE Ltd, работающая на Украине и у неё получается самый прибыльный суммарный чек. Вспомним компанию Medline. В ТОР 10 она не попала. Впомнилась пословица, лучше синица в руке, чем журавль в небе. Получается, при высокой активности и стабильности на рынке, компания не делает высокую наценку на товары.

# %% [markdown]
# Здесь, в принципе, можно и закончить разведочный анализ данных. Датасет, конечно, содержит на много больше аспектов для исследования, и можно его заключить в отдельную работу, но ограничусь тем, что сделал общий обзор.

# %% [markdown]
# # Машинное обучение. Pycaret vv.3.0.0rc6

# %% [markdown]
# ссылка на блокнот https://colab.research.google.com/drive/1yF7LQHYHooH90xrxIjTINV2CXut9LK4F?usp=sharing

# %% [markdown]
# Загрузил основные библиотеки. Библиотеку Numpy пришлось обновить, так требует pycaret.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# загрузил базу и проверил форматы. Так как буду предсказывать отток, а он имеет стороковый тип, изменил на цифровой. Также поменял форматы даты

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Импортируя библиотеку и загрузив данные, разделённые на 90 и 10 процентов. обучающая и тестовая выборка соотвественно. Причём тестовая выборка участвовать в процессе машинного обучения не будет. После загрузки, программа сама разбила датасет на составляющие, необходимые для начала обучения.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# далее, запустив одну строчку кода, машина сама перекрёстно обсчитывает модели и выявляет лучшую.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# лучшая оказалась модель дерево решений.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# После ещё некоторых преобразований запустил модель на данных которые модель не видела.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# На этом остановимся. результат очень даже. Вспомним Loginom там модель давала 91,63 %.  Здесь же модель выдала 99,56%. Думаю, комментарии здесь излишни. Модель можно отдавать разработчикам приложений для интеграции.

# %% [markdown]
# # Power BI

# %% [markdown]
# ссылка на pdf файл https://drive.google.com/file/d/1cLmxgQ7tXbZu-Y8q5EsLJYrI1juCHQLi/view?usp=share_link

# %% [markdown]
# описывает основную визуализацию итоговой работы. К большому сожалению не могу показать в интерактивной среде, из-за технических проблем, но вкраце расскажу.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# на данном скришоте показаны основные показатели итоговой таблицы. На карте это распределение суммарных продаж по городам и странам. Окошки вверху показывают прибыль по клиентам и продукту. Также показаны общее количество заказов, себестоимоть и маржу.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# здесь, на карте показаны насколько ликвидны склады на территориях стран европы и их активность. Гистограммой показано прибыль и продажи по компаниям за перид 2014-2017 годов. В круговой диаграмме показаны доля деятельности компаний: экспорт, дистрибьютерсво, оптовые продажи. Плиткой отражён другой вариант , к ним добавляется и время.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Не очень интересные диаграммы, показана динамика продаж по количеству товаров относительно скадов и наименования продуктов. Есть интересные моменты, если углубиться, на дни недели.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Здесь оценены сегменты анализа по прибыл. К сожалению, почему то при переводе в pdf файл, сохранилось не так как хотел. На втором графике показал прибыль по компаниям отдельно.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Очень удобная древовидная структура визуализации. Здесь показал как распределяется маржа по 7 продукту, т.к он самый популярный.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Здесть воспользовался функционалом вопросы-ответы. Если бы побольше времени, то изобрёл бы сам, но думаю это в будущем. Получились графики дублирующие первый скриншот. Там в цвете вторых и последующих можно ошибится. Здесь же наглядно показывает ТОР10 стран и городов.

# %% [markdown]
# # ВЫВОД

# %% [markdown]
# По итоговой работе было проведёно слияние таблиц и насыщение данными. Использовал платфому Bigquery и Loginom. Проведен разведочный анализ EDA данных на основе библиотек на языке программирования Python, а также создание модели машинного обучения и её запуск на фреймворках Loginom и Pycaret. Для визуализации данных использовал настольную версию PowerBI. На платформу зайти не удалось.
#
# Анализ показал, что есть 50 компаний торгущие чем то медицинским (по одному из названий, компании Medline) в 26 странах и 66 городах. Общий объём продаж составил более 150 млн. долларов и прибыль компаний составила 57,8 млн. долларов. Основная деятельность компаний приходилась на Германию, а самый активный город оказался в Испании (Барселона). сезонность при деятельности компаний не наблюдалось,однако к новому году, деятельность практически прекращали. Машинное обучение и анализ показал, что в первый год (2014) компании могли закрытся, но из анализа они выправили положение и остальное время работали стабильно. Конечно машинное обучение можно было вести и по временным рядам, прогнозируя продажи на следующий период. Но этот пример тоже показателен, особенно для компаний на этапе стартапа. Какие негативные ситуации можно предусматретью Для более глубокого анализа я бы взял в будущем, именно 2014 год. Сравнивая, настольную версию Loginom и библиотеку на python Pycaret можно сказать, что Loginom уступил не много Pycaret. Распознание закрытия компаний составили 91,63% и 99,56% соответственно. Тем не менее это не плохой результат. Вручную машинное обучение не делал за не имением времени, но меня это не пугает, т.к. я имею опыт в этой области.
#
# За прошедший курс научился работать на платформах LookerStudio, Bigquery, KNIME,RapidMiner, Tableau. Также приобрёл опыт работы в PowerBI, Loginom. Познакомился со множеством библиотек на языке Python. Научился делать разведовательный анализ данных EDA. Курс занимал очень много времени, но оказался очень познавательным и полезным. Особо хочу поблагодарить Сахнюк Павла Анатольевича, Крапивину Наталью Юрьевну и Прохоренко Алексея за очень насыщенную и полезную информацию, помощь в вопросах обучения.

# %% [markdown]
# # ссылки на блокноты

# %% [markdown]
# ссылка на Loginom файл https://drive.google.com/file/d/1ses5UEhvgp4POCPlxhp4M235JcHl9mWv/view?usp=share_link
#
# ссылка блокнот Pandas-profilling https://colab.research.google.com/drive/1xp46UZlplId2jGNUEosHyqyStXJf7kh8?usp=sharing
#
# ссылка на LUX  https://colab.research.google.com/drive/12N0STwEc7JaKjbGvVwEDTrh3u80TJw-a?usp=sharing
#
# ссылка на Pycaret https://colab.research.google.com/drive/1yF7LQHYHooH90xrxIjTINV2CXut9LK4F?usp=sharing
#
# ссылка на файл pdf powerBI ссылка на pdf файл https://drive.google.com/file/d/1cLmxgQ7tXbZu-Y8q5EsLJYrI1juCHQLi/view?usp=share_link
